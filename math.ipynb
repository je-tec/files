# %% [markdown]
# <a href="https://colab.research.google.com/github/je-tec/files/blob/main/math.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
resultado = 10 + 5
print("El resultado de la suma es: ", resultado)

# %%
resultado = 10 - 4
print("El resultado de la resta es: ", resultado)

# %%
resultado = 6 * 3
print("El resultado de la multiplicación es: ", resultado)

# %%
resultado = 10 / 2
print("El resultado de la división es: ", resultado)

resultado = 10 // 3
print("El resultado de la división entera es: ",resultado)

# %%
resultado = 10 % 3
print("El resultado de la residuo de la división es: ", resultado)
# Out:
# El resultado de la residuo de la división es:  1

# %%
resultado = 2 ** 3  # (2 * 2 * 2)
print(resultado)
